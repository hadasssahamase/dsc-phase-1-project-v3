# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Amase Oyakapeli
# * Student pace: self paced / part time / full time - full time
# * Scheduled project review date/time:
# * Instructor name: William
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %% [markdown]
# Business understanding
# Objectives
# which aircrafts pose low risk investment?
# between commercial and private aircrafts which are good for a start-up?

# %% [markdown]
# Data Understanding

# %%
# importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
# loading the data set
cwd = os.getcwd()
print(cwd)
df = pd.read_csv('C:/Users/ADMIN/OneDrive/Desktop/New folder/dsc-phase-1-project-v3/data/Aviation_Data.csv', encoding='latin1')
df
# Out:
# C:\Users\ADMIN\OneDrive\Desktop\New folder\dsc-phase-1-project-v3
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23064\614448483.py:4: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/ADMIN/OneDrive/Desktop/New folder/dsc-phase-1-project-v3/data/Aviation_Data.csv', encoding='latin1')
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# ...

# %%
# checking for consistency
# getting thw first 5 rows
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# 4       Canton, OH  United States        NaN        NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
# checking the last 5 rows
df.tail()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#             Location        Country Latitude Longitude Airport.Code  \
# 90343  Annapolis, MD  United States      NaN       NaN          NaN
# 90344    Hampton, NH  United States      NaN       NaN          NaN
# 90345     Payson, AZ  United States  341525N  1112021W          PAN
# 90346     Morgan, UT  United States      NaN       NaN          NaN
# 90347     Athens, GA  United States      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 90343          NaN  ...          Personal                 NaN
# ...

# %%
# checking the number of rows and the number of columns
df.shape
# Out:
# (90348, 31)

# %%
# stastical summary
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
# categorical summary
df.describe(include="O")
# Out:
#               Event.Id Investigation.Type Accident.Number  Event.Date  \
# count            88889              90348           88889       88889
# unique           87951                 71           88863       14782
# top     20001212X19172           Accident      CEN22LA149  1984-06-30
# freq                 3              85015               2          25
#
#              Location        Country Latitude Longitude Airport.Code  \
# count           88837          88663    34382     34373        50132
# unique          27758            219    25592     27156        10374
# top     ANCHORAGE, AK  United States  332739N  0112457W         NONE
# freq              434          82248       19        24         1488
#
#        Airport.Name  ... Amateur.Built    Engine.Type FAR.Description  \
# count         52704  ...         88787          81793           32023
# unique        24870  ...             2             12              31
# ...

# %%
# checking the data types and also abit of null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %% [markdown]
# Data Preparation
# This involves data cleaning by finding and clearing missing values,dropping rows or columns,filtering data,adding relevant columns

# %%
# creating a copy of the dataframe
df1 = df.copy(deep=True)
df1.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# 4       Canton, OH  United States        NaN        NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
# identify where df1 is a series or data frame
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# changing all columns in lower case
df1.columns = df1.columns.str.lower()
df1
# Out:
#              event.id investigation.type accident.number  event.date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               location        country   latitude  longitude airport.code  \
# ...

# %%
# checking missing values 
df1.isna().sum()
# Out:
# event.id                   1459
# investigation.type            0
# accident.number            1459
# event.date                 1459
# location                   1511
# country                    1685
# latitude                  55966
# longitude                 55975
# airport.code              40216
# airport.name              37644
# injury.severity            2459
# aircraft.damage            4653
# aircraft.category         58061
# registration.number        2841
# make                       1522
# model                      1551
# amateur.built              1561
# number.of.engines          7543
# engine.type                8555
# far.description           58325
# schedule                  77766
# purpose.of.flight          7651
# air.carrier               73700
# total.fatal.injuries      12860
# total.serious.injuries    13969
# total.minor.injuries      13392
# total.uninjured            7371
# weather.condition          5951
# broad.phase.of.flight     28624
# ...

# %%
df1.columns
# Out:
# Index(['event.id', 'investigation.type', 'accident.number', 'event.date',
#        'location', 'country', 'latitude', 'longitude', 'airport.code',
#        'airport.name', 'injury.severity', 'aircraft.damage',
#        'aircraft.category', 'registration.number', 'make', 'model',
#        'amateur.built', 'number.of.engines', 'engine.type', 'far.description',
#        'schedule', 'purpose.of.flight', 'air.carrier', 'total.fatal.injuries',
#        'total.serious.injuries', 'total.minor.injuries', 'total.uninjured',
#        'weather.condition', 'broad.phase.of.flight', 'report.status',
#        'publication.date'],
#       dtype='object')

# %%
# checking all unique values in the column country
df1['country'].unique()
# Out:
# array(['United States', nan, 'GULF OF MEXICO', 'Puerto Rico',
#        'ATLANTIC OCEAN', 'HIGH ISLAND', 'Bahamas', 'MISSING', 'Pakistan',
#        'Angola', 'Germany', 'Korea, Republic Of', 'Martinique',
#        'American Samoa', 'PACIFIC OCEAN', 'Canada', 'Bolivia', 'Mexico',
#        'Dominica', 'Netherlands Antilles', 'Iceland', 'Greece', 'Guam',
#        'Australia', 'CARIBBEAN SEA', 'West Indies', 'Japan',
#        'Philippines', 'Venezuela', 'Bermuda', 'San Juan Islands',
#        'Colombia', 'El Salvador', 'United Kingdom',
#        'British Virgin Islands', 'Netherlands', 'Costa Rica',
#        'Mozambique', 'Jamaica', 'Panama', 'Guyana', 'Norway', 'Hong Kong',
#        'Portugal', 'Malaysia', 'Turks And Caicos Islands',
#        'Northern Mariana Islands', 'Dominican Republic', 'Suriname',
#        'Honduras', 'Congo', 'Belize', 'Guatemala', 'Anguilla', 'France',
#        'St Vincent And The Grenadines', 'Haiti', 'Montserrat',
# ...

# %%
# dropping a all other countries except United state in the column countries
df1.drop(df1[df1['country'] != 'United States'].index, inplace=True)
df1
# Out:
#              event.id investigation.type accident.number  event.date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               location        country   latitude  longitude airport.code  \
# ...

# %%
# confirming that united states is the only one left
df1['country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
# dropping the longitudes and latitudes columns
df1 = df1.drop(['latitude', 'longitude','event.id'], axis=1)

# %%
df1.describe()
# Out:
#        number.of.engines  total.fatal.injuries  total.serious.injuries  \
# count       80373.000000          71594.000000            70873.000000
# mean            1.135481              0.421683                0.257178
# std             0.427286              2.433647                1.144189
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            265.000000              137.000000
#
#        total.minor.injuries  total.uninjured
# count          71519.000000     77243.000000
# mean               0.332974         4.302448
# std                1.306604        23.794728
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
# filling categorical data using a variable
y_columns = ['injury.severity', 'aircraft.damage', 'total.fatal.injuries']

for col in y_columns:
    df1[col] = df1[col].fillna('Unknown')
df1
# Out:
#       investigation.type accident.number  event.date         location  \
# 0               Accident      SEA87LA080  1948-10-24  MOOSE CREEK, ID
# 1               Accident      LAX94LA336  1962-07-19   BRIDGEPORT, CA
# 2               Accident      NYC07LA005  1974-08-30    Saltville, VA
# 3               Accident      LAX96LA321  1977-06-19       EUREKA, CA
# 4               Accident      CHI79FA064  1979-08-02       Canton, OH
# ...                  ...             ...         ...              ...
# 90343           Accident      ERA23LA093  2022-12-26    Annapolis, MD
# 90344           Accident      ERA23LA095  2022-12-26      Hampton, NH
# 90345           Accident      WPR23LA075  2022-12-26       Payson, AZ
# 90346           Accident      WPR23LA076  2022-12-26       Morgan, UT
# 90347           Accident      ERA23LA097  2022-12-29       Athens, GA
#
#              country airport.code airport.name injury.severity  \
# ...

# %%
# Drop columns with more than 50% missing values - schedule and air.carrier
threshold = 0.5 * len(df1)
df1 = df1.dropna(thresh=threshold, axis=1)

# %%
# filling numerical columns total.fatal.injuries,number.of.engines using median

# Identify numerical columns
numerical_cols = ['total.fatal.injuries', 'number.of.engines']

# Fill missing values in each numerical column with its median
for col in numerical_cols:
    df1.loc[:, col] = pd.to_numeric(df1[col], errors='coerce') 
    df1[col] = df1[col].fillna(df1[col].median())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23064\3379110529.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1[col] = df1[col].fillna(df1[col].median())
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23064\3379110529.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].fillna(df1[col].median())

# %%
# checking the number of missing values in the dataset
df1.isna().sum()
# Out:
# investigation.type            0
# accident.number               0
# event.date                    0
# location                     11
# country                       0
# airport.code              33176
# airport.name              30678
# injury.severity               0
# aircraft.damage               0
# registration.number         116
# make                         21
# model                        38
# amateur.built                21
# number.of.engines             0
# engine.type                3042
# purpose.of.flight          2429
# total.fatal.injuries          0
# total.serious.injuries    11375
# total.minor.injuries      10729
# total.uninjured            5005
# weather.condition           645
# broad.phase.of.flight     21090
# report.status              2611
# publication.date          14138
# dtype: int64

# %%
df1.shape
# Out:
# (82248, 24)

# %%
# Data distribution
df1.hist(bins=17, figsize=(20,12));

# %% [markdown]
# General Insights
# Most airplanes use one engine.
# The total uninjured is

# %%
# Only select numeric columns 
numeric_columns = df.select_dtypes(include=['number']).columns[:]

# Define grid layout 
rows, cols = 2,3
fig, axes = plt.subplots(rows, cols, figsize=(21,13))

# Flatten the arrays 
axes = axes.flatten()

# Plot histograms for numeric columns 
for i, column in enumerate(numeric_columns):
    sns.histplot(df[column], bins=20, ax=axes[i])
    axes[i].set_title(f'Histogram for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Frequency')
    
    
# Hide empty subplots 
for j in range (i + 1, rows * cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
# checking for outliers
sns.boxplot(df1)
plt.xticks(rotation=45, ha='right', fontsize=12)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'number.of.engines'),
#   Text(1, 0, 'total.fatal.injuries'),
#   Text(2, 0, 'total.serious.injuries'),
#   Text(3, 0, 'total.minor.injuries'),
#   Text(4, 0, 'total.uninjured')])

# %% [markdown]
# Univariate Analysis

# %%
# analysis purposes of flights

# Create the bar chart
flight = df1['purpose.of.flight'].value_counts().reset_index()
flight.columns = ['purpose_of_flight', 'count']

plt.figure(figsize=(10, 6))  # Increase figure size for clarity

# Create the bar chart
plt.bar(flight['purpose_of_flight'], flight['count'], color='skyblue')

# Add labels and title
plt.xlabel('Purpose of Flight', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Flight Purpose Distribution', fontsize=16)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=45, ha='right', fontsize=12)


# Add extra padding at the bottom for x-axis labels
plt.subplots_adjust(bottom=0.2)

# Display the plot
plt.tight_layout()
plt.show()

# %% [raw]
# # from the above analysis we can see personal flights are the highest in the united states

# %%
# analysis makes of aeroplanes
# make all values in the column 'make' into lowercase 
df1['make']=df1['make'].str.lower()
df1['make']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23064\474230245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['make']=df1['make'].str.lower()
# 0                           stinson
# 1                             piper
# 2                            cessna
# 3                          rockwell
# 4                            cessna
#                     ...
# 90343                         piper
# 90344                      bellanca
# 90345    american champion aircraft
# 90346                        cessna
# 90347                         piper
# Name: make, Length: 82248, dtype: object

# %%
df1['make'].duplicated().value_counts()

# %%
 # Total fatal injuries by aircraft model
fatal_injuries_by_model = df1.groupby('model')['total.fatal.injuries'].sum().sort_values()

# Plot the top 10 safest models (least fatal injuries)
fatal_injuries_by_model.head(10).plot(kind='bar', title='Top 10 Safest Aircraft Models')
# Out:
# <Axes: title={'center': 'Top 10 Safest Aircraft Models'}, xlabel='model'>

# %%
# Count of accidents by flight phase
accidents_by_phase = df1['broad.phase.of.flight'].value_counts()

# Plot the flight phases with accidents
accidents_by_phase.plot(kind='bar', title='Accidents by Flight Phase')
# Out:
# <Axes: title={'center': 'Accidents by Flight Phase'}, xlabel='broad.phase.of.flight'>

# %%
# Weather conditions and severity
weather_severity = df1.groupby('weather.condition')['total.fatal.injuries'].sum()

# Plot weather conditions vs. fatal injuries
weather_severity.plot(kind='bar', title='Weather Impact on Fatal Injuries')
# Out:
# <Axes: title={'center': 'Weather Impact on Fatal Injuries'}, xlabel='weather.condition'>

# %%
# Group by 'make' and 'model' and aggregate injuries
safety_by_make_model = df1.groupby(['make', 'model'])[
    ['total.fatal.injuries', 'total.serious.injuries', 'total.minor.injuries']
 ].sum()

# Add a 'total injuries' column
safety_by_make_model['total.injuries'] = safety_by_make_model.sum(axis=1)

# Get the safest aircraft (least total injuries)
safest_aircraft = safety_by_make_model.sort_values(by='total.injuries').head(10)
print(safest_aircraft)
# Out:
#                                            total.fatal.injuries  \
# make                       model
# hesterlee                  RUTAN VARI EZE                   0.0
# hiller                     UH-12L3                          0.0
#                            UH-12L4                          0.0
#                            UH-23-D                          0.0
#                            UH12-C                           0.0
#                            UH12D                            0.0
#                            UH12DJ3                          0.0
#                            UH-12E4                          0.0
#                            UH21E                            0.0
# hiller-rogerson helicopter UH12E                            0.0
#
#                                            total.serious.injuries  \
# make                       model
# hesterlee                  RUTAN VARI EZE                     0.0
# ...

# %%
# Count accidents by engine type
accidents_by_engine = df1['engine.type'].value_counts()

# Total injuries by engine type
injuries_by_engine = df1.groupby('engine.type')['total.fatal.injuries'].sum()

# Plot injuries by engine type
injuries_by_engine.plot(kind='bar', title='Injuries by Engine Type')
# Out:
# <Axes: title={'center': 'Injuries by Engine Type'}, xlabel='engine.type'>

# %% [markdown]
# Correlation Matrix

# %%
numeric_df1 = df1.select_dtypes(include=["number"])


correlation_matrix = numeric_df1.corr()

plt.figure(figsize=(23, 9))


sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.1)

plt.title("Correlation_matrix")

plt.tight_layout()
plt.show()

# %%
# sns.scatterplot(x='bank_asset_value',y='loan_amount', data=df, hue='loan_status')

# %% [markdown]
# Multivariate Analysis

# %%
sns.scatterplot(x='total.fatal.injuries',y='number.of.engines',data=df1,hue='weather.condition')
# Out:
# <Axes: xlabel='total.fatal.injuries', ylabel='number.of.engines'>

# %%
# saving the clean data set
# df1.to_csv("Aviation_data_clean.csv",index=False)
